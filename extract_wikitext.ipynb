# %%
import requests

# %%
with open("cleanversion3") as f:
    text = f.read()

# %%
text
# Out:
# 'Wikidata:WikiProject_Civil_Defense/List_of_emergency_medical_services_organizations\nWikidata:WikiProject_Civil_Defense/List_of_rescue_organizations\nWikidata:WikiProject_Civil_Defense/List_of_law_enforcement_agencies\nWikidata:WikiProject_Civil_Defense/List_of_law_enforcement_agencies/Brazil\nWikidata:WikiProject_Civil_Defense/List_of_nuclear_power_plants\nWikidata:WikiProject_Civil_Defense/List_of_dykes\nWikidata:WikiProject_Civil_Defense/List_of_dams\nWikidata:WikiProject_Civil_Defense/List_of_dams/Brazil\nWikidata:WikiProject_Civil_Defense/List_of_shelters\nWikidata:WikiProject_Civil_Defense/List_of_firefighting_organizations/Brazil\nWikidata:WikiProject_Civil_Defense/List_of_aerodromes\nWikidata:WikiProject_IFRC/List/Tree\nWikidata:WikiProject_20th_Century_Press_Archives/Tools_%26_Tasks/Subject_Category_checks\nWikidata:WikiProject_Climate_Change/Queries\nWikidata:WikiProject_Climate_Change/Models\nWikidata:WikiProject_Civil_Defense/List_of_emergency_management_governmental_agencies/419\nWikidata:WikiProject_Civil_Defense/List_of_crematories\nWikidata:WikiProject_Slovakia/Properties/szl\nWikidata:SPARQL_query_service/queries/examples/th\nWikidata:WikiProject_Music/es\nWikidata:Open-source_hardware\nWikidata:WikiProject_Music/ms-arab\nWikidata:WikiProject_Music/ms\nWikidata:WikiProject_Chemistry_Natural_products/en\nWikidata:WikiProject_Chemistry_Natural_products/fr\nWikidata:WikiProject_Music/bn\nWikidata:WikiProject_Music/syl\nWikidata:WikiProject_Chemistry_Natural_products/ru\nWikidata:Lexicographical_data/Malayalam/Queries\nWikidata:WikiProject_Chemistry_Natural_products/it\nWikidata:WikiProject_Government/Report/Greenland\nWikidata:WikiProject_Chemistry_Natural_products/de\nWikidata:WikiProject_Ethnomusicological_descriptors_-_University_of_Turin/Queries\nWikidata:WikiProject_Punjab/Queries\nWikidata:WikiProject_Lodging/Queries\nWikidata:WikiProject_Music/id\nWikidata:WikiProject_Chemistry/Issues_with_InChI_and_InChIKey\nWikidata:WikiProject_Music/dtp\nWikidata:WikiProject_Manuscripts/Data_Model\nWikidata:SPARQL_query_service/queries/examples/advanced/ja\nWikidata:WikiProject_Music/ca\nWikidata:SPARQL_query_service/queries/examples/advanced/nl\nWikidata:WikiProject_Music/zh\nWikidata:WikiProject_Music/he\nWikidata:WikiProject_Music/pt\nWikidata:WikiProject_Music/ha\nWikidata:WikiProject_Slovakia/Properties/nl\nWikidata:WikiProject_Slovakia/Showcase_Queries/nl\nWikidata:WikiProject_Chemistry_Natural_products/nl\nWikidata:WikiProject_Music/be-tarask\nWikidata:SPARQL_query_service/queries/examples/lb\nWikidata_talk:WikiProject_Physics\nWikidata_talk:SPARQL_query_service/queries\nWikidata_talk:WikiProject_Award\nWikidata_talk:SPARQL_query_service/queries/examples\nWikidata_talk:WikiProject_Equines\nWikidata_talk:SPARQL_query_service/queries/Archive/2016\nWikidata_talk:Status_updates/Next/Archive_1\nWikidata_talk:WikiProject_Informatics/Software/Operating_systems\nWikidata_talk:WikiProject_Ontology/Modelling\nWikidata_talk:WikiProject_Policies\nWikidata_talk:WikiProject_Source_MetaData/Archive_4\nWikidata_talk:WikiProject_Chemistry/Archive/2019\nWikidata_talk:CopyClear\nWikidata_talk:WikiProject_COVID-19/Archive\nWikidata_talk:Dataset_Imports/Archaeology_Data_Service_author_IDs\nWikidata_talk:Lexicographical_data/Archive/2021/06\nWikidata_talk:Lexicographical_data/Archive/2021/08\nWikidata_talk:WikiProject_Ontology/Archive_2\nTemplate:SPARQL\nTemplate:SPARQL/doc\nTemplate:SPARQL2\nTemplate:SPARQL2/doc\nTemplate:SPARQL/sandbox\nTemplate:Query_page/style/SPARQL2\nTemplate:SPARQL_Inline\nTemplate:SPARQL_Inline/doc\nTemplate:SPARQL_Box\nTemplate:SPARQL_Box/doc\nTemplate:SPARQL-results/doc\nTemplate:Sandbox/Azertus/SPARQL2\nTemplate_talk:Item_documentation\nTemplate_talk:Property_documentation/Archive_2\nTemplate_talk:Query_page/sandbox\nTemplate_talk:Query_page/sandbox_2\nHelp:Templates\nHelp_talk:Redirects\nProperty_talk:P131\nProperty_talk:P460\nProperty_talk:P1616\nProperty_talk:P1889\nProperty_talk:P3096\nModule:Sandbox/A ...

# %%
lines = text.split("\n")

# %%
lines
# Out:
# ['Wikidata:WikiProject_Civil_Defense/List_of_emergency_medical_services_organizations',
#  'Wikidata:WikiProject_Civil_Defense/List_of_rescue_organizations',
#  'Wikidata:WikiProject_Civil_Defense/List_of_law_enforcement_agencies',
#  'Wikidata:WikiProject_Civil_Defense/List_of_law_enforcement_agencies/Brazil',
#  'Wikidata:WikiProject_Civil_Defense/List_of_nuclear_power_plants',
#  'Wikidata:WikiProject_Civil_Defense/List_of_dykes',
#  'Wikidata:WikiProject_Civil_Defense/List_of_dams',
#  'Wikidata:WikiProject_Civil_Defense/List_of_dams/Brazil',
#  'Wikidata:WikiProject_Civil_Defense/List_of_shelters',
#  'Wikidata:WikiProject_Civil_Defense/List_of_firefighting_organizations/Brazil',
#  'Wikidata:WikiProject_Civil_Defense/List_of_aerodromes',
#  'Wikidata:WikiProject_IFRC/List/Tree',
#  'Wikidata:WikiProject_20th_Century_Press_Archives/Tools_%26_Tasks/Subject_Category_checks',
#  'Wikidata:WikiProject_Climate_Change/Queries',
#  'Wikidata:WikiProject_Climate_Change/Models',
#  'Wikidata:WikiProject_Civil_Defense/List_of_emergency_management_governmental_agencies/419',
#  'Wikidata:WikiProject_Civil_Defense/List_of_crematories',
#  'Wikidata:WikiProject_Slovakia/Properties/szl',
#  'Wikidata:SPARQL_query_service/queries/examples/th',
#  'Wikidata:WikiProject_Music/es',
#  'Wikidata:Open-source_hardware',
#  'Wikidata:WikiProject_Music/ms-arab',
#  'Wikidata:WikiProject_Music/ms',
#  'Wikidata:WikiProject_Chemistry_Natural_products/en',
#  'Wikidata:WikiProject_Chemistry_Natural_products/fr',
#  'Wikidata:WikiProject_Music/bn',
#  'Wikidata:WikiProject_Music/syl',
#  'Wikidata:WikiProject_Chemistry_Natural_products/ru',
#  'Wikidata:Lexicographical_data/Malayalam/Queries',
#  'Wikidata:WikiProject_Chemistry_Natural_products/it',
#  'Wikidata:WikiProject_Government/Report/Greenland',
#  'Wikidata:WikiProject_Chemistry_Natural_products/de',
#  'Wikidata:WikiProject_Ethnomusicological_descriptors_-_University_of_Turin/Queries',
#  'Wikidata:WikiProject_Punjab/Queries',
#  'Wikidata:WikiProject_Lodging/Queries',
#  'Wikidata:WikiProject_Music/id',
#  'Wikidata:WikiProject_Chemistry/Issues_with_InChI_and_InChIKey',
#  'Wikidata:WikiProject_Music/dtp',
#  'Wikidata:WikiProject_Manuscripts/Data_Model',
#  'Wikidata:SPARQL_query_service/queries/examples/advanced/ja',
#  'Wikidata:WikiProject_Music/ca',
#  'Wikidata:SPARQL_query_service/queries/examples/advanced/nl',
#  'Wikidata:WikiProject_Music/zh',
#  'Wikidata:WikiProject_Music/he',
#  'Wikidata:WikiProject_Music/pt',
#  'Wikidata:WikiProject_Music/ha',
#  'Wikidata:WikiProject_Slovakia/Properties/nl',
#  'Wikidata:WikiProject_Slovakia/Showcase_Queries/nl',
#  'Wikidata:WikiProject_Chemistry_Natural_products/nl',
#  'Wikidata:WikiProject_Music/be-tarask',
#  'Wikidata:SPARQL_query_service/queries/examples/lb',
#  'Wikidata_talk:WikiProject_Physics',
#  'Wikidata_talk:SPARQL_query_service/queries',
#  'Wikidata_talk:WikiProject_Award',
#  'Wikidata_talk:SPARQL_query_service/queries/examples',
#  'Wikidata_talk:WikiProject_Equines',
#  'Wikidata_talk:SPARQL_query_service/queries/Archive/2016',
#  'Wikidata_talk:Status_updates/Next/Archive_1',
#  'Wikidata_talk:WikiProject_Informatics/Software/Operating_systems',
#  'Wikidata_talk:WikiProject_Ontology/Modelling',
#  'Wikidata_talk:WikiProject_Policies',
#  'Wikidata_talk:WikiProject_Source_MetaData/Archive_4',
#  'Wikidata_talk:WikiProject_Chemistry/Archive/2019',
#  'Wikidata_talk:CopyClear',
#  'Wikidata_talk:WikiProject_COVID-19/Archive',
#  'Wikidata_talk:Dataset_Imports/Archaeology_Data_Service_author_IDs',
#  'Wikidata_talk:Lexicographical_data/Archive/2021/06',
#  'Wikidata_talk:Lexicographical_data/Archive/2021/08',
#  'Wikidata_talk:WikiProject_Ontology/Archive_2',
#  'Template:SPARQL',
#  'Template:SPARQL/doc',
#  'Template:SPARQL2',
#  'Template:SPARQL2/doc',
#  'Template:SPARQL/sandbox',
#  'Template:Query_page/style/SPARQL2',
#  'Template:SPARQL_Inline',
#  'Template:SPARQL_Inline/doc',
#  'Template:SPARQL_Box',
#  'Template:SPARQL_Box/doc',
#  'Template:SPARQL-results/doc',
#  'Template:Sandbox/Azertus/SPARQL2',
#  'Template_talk:Item_documentation',
#  'Template_talk:Property_documentation/Archive_2',
#  'Template_talk:Query_page/sandbox',
#  'Template_talk:Query_page/sandbox_2',
#  'Help:Templates',
#  'Help_talk:Redirects',
#  'Property_talk:P131',
#  'Property_talk:P460',
#  'Property_talk:P1616',
#  'Property_talk:P1889',
#  'Property_talk:P3096',
#  'Module:Sandbox/Azertus/SPARQLMentions',
#  'Module:Sandbox/Azertus/SPARQLMentions/doc',
#  'Topic:Ta6dmhnqcbkywrvj',
#  'Topic:Tgdn18d8alfjbpby',
#  'Topic:Trg7ibknovzj0yn8',
#  'Topic:Ts15injtw8f9147m',
#  'Topic:Tsmd5uxlbj43zyo1',
#  'Topic:Tvdhysswb4ldnwle',
#  'Topic:Uddqztd73t48rvdy',
#  'Topic:Uod3x2ssor6pn5ys',
#  'Topic:Upahybt3xiknpmyq',
#  'Topic:Uzlbj6c1cys1h234',
#  'Topic:Vunxye1m0bnuj6ap',
#  'Topic:Wps7qokf58ewsy0i',
#  'Topic:Wxlkx21g7pa3dw5l',
#  'Topic:Wxxfud2aubxfa6q7',
#  'Topic:Xdjb0agvg0o7ltrd',
#  'Talk:Q87572880',
#  'Talk:Q111539301',
#  'Talk:Q312499',
#  'User:Daniel_Mietchen',
#  'User:Gerd_Fahrenhorst',
#  'User:Dhx1',
#  'User:Toto256',
#  'User:Silanoc',
#  'User:Hofoen',
#  'User:Daniel_Mietchen/sandbox',
#  'User:Richard_Arthur_Norton_(1958-_)',
#  'User:Samwilson',
#  'User:Jtuom',
#  'User:XXN/q',
#  'User:Realworldobject',
#  'User:Realworldobject/ShowTell',
#  'User:M%C3%A1t%C3%A9/ratings',
#  'User:Frog23',
#  'User:Ash_Crow/SPARQL',
#  'User:Smalyshev_(WMF)/TestQ',
#  'User:Rama',
#  'User:YULdigitalpreservation/SPARQL',
#  'User:Research_Bot',
#  'User:MartinPoulter/queries',
#  'User:Aeroid/SPARQL_Notes',
#  'User:M%C3%A1t%C3%A9/ratings/years',
#  'User:M%C3%A1t%C3%A9/ratings/MSD',
#  'User:MKar/Query',
#  'User:Jarekt/queries',
#  'User:HLa01',
#  'User:Looniverse',
#  'User:Looniverse/SPARQL',
#  'User:Looniverse/SPARQL4IT',
#  'User:Smalyshev_(WMF)/Federation',
#  'User:Daniel_Mietchen/Bioinformatics',
#  'User:Witia/Help',
#  'User:Looniverse/Bundestagswahl',
#  'User:MartinPoulter/queries/ee',
#  'User:Richard_Nevell',
#  'User:ProteinBoxBot/Maintenance_Queries',
#  'User:Realworldobject/DataAnalytics',
#  'User:Datumizer/List_of_role-playing_video_games',
#  'User:ProteinBoxBot/SPARQL_Examples',
#  'User:YULdigitalpreservation/SPARQL2',
#  'User:MartinPoulter/queries/hillforts',
#  'User:AllyD/sandbox',
#  'User:Touam',
#  'User:Lucas_Werkmeister_(WMDE)/Query_example',
#  'User:Netha_Hussain/Query_list',
#  'User:Hweyl/sparql',
#  'User:Jonas_Kress_(WMDE)/SPARQL_QUERIES',
#  'User:Lucas_Werkmeister_(WMDE)/SPARQL_queries',
#  'User:D1gggg/Wikidata_model_and_SPARQL',
#  'User:Pathwaybot/query_examples',
#  'User:Mr._Ibrahem/queries',
#  'User:Geertivp/training/Wikidata_Query',
#  'User:Geertivp/training/Wikidata_Query/Missing_description_in_target_language',
#  'User:Geertivp/training/Wikidata_Query/Symmetric_constraint_error',
#  'User:Geertivp/training/Wikidata_Query/Country_constraint_error',
#  'User:Variantbot/data_model',
#  'User:Geertivp/training/Wikidata_Query/Label_equal_to_Description',
#  'User:Geertivp/training/Wikidata_Query/Missing_label_in_target_language',
#  'User:Satdeep_Gill/Query',
#  'User:Geertivp/training/Wikidata_Query/Inverse_constraint_error',
#  'User:Geertivp/training/Wikidata_Query/Sub-municipality_missing_part_of_municipality',
#  'User:Geertivp/training/Wikidata_Query/Label_equal_to_Alias',
#  'User:Geertivp/training/Wikidata_Query/Geolocation/Languages_in_Belgium',
#  'User:Geertivp/training/Wikidata_Query/Geolocation/Buildings_in_The_Netherlands',
#  'User:Geertivp/training/Wikidata_Query/Female_brewer',
#  'User:Geertivp/training/Wikidata_Query/Belgian_Cyclists',
#  'User:Geertivp/training/Wikidata_Query/Intro',
#  'User:Geertivp/training/Wikidata_Query/Sex_no_man',
#  'User:MKar/sandbox',
#  'User:Geertivp/training/Wikidata_Query/Belgian_Enterprise',
#  'User:Geertivp/training/Wikidata_Query/Person_with_missing_profession',
#  'User:Geertivp/training/Wikidata_Query/Not_all_Females_are_Human',
#  'User:Geertivp/training/Wikidata_Query/Nationality_not_human',
#  'User:Geertivp/training/Wikidata_Query/Musea_with_most_paintings',
#  'User:Geertivp/training/Wikidata_Query/List_of_musea_by_country',
#  'User:Geertivp/training/Wikidata_Query/gender_friendly_titles',
#  'User:Geertivp/training/Wikidata_Query/Literary_work',
#  'User:Geertivp/training/Wikidata_Query/Genre_of_art',
#  'User:Geertivp/training/Wikidata_Query/Undefined_professions',
#  'User:Geertivp/training/Wikidata_Query/List_of_Female_scientists',
#  'User:Geertivp/training/Wikidata_Query/Building_in_Belgium',
#  'User:Geertivp/training/Wikidata_Query/Church_in_Belgium',
#  'User:Ogmios/HBK',
#  'User:Frog23/My_Queries',
#  'User:Ppassage',
#  'User:MartinPoulter/queries/collections',
#  'User:Cmuelle8',
#  'User:YULdigitalpreservation/ScienceStories',
#  'User:Ogmios/CLZ',
#  'User:YULdigitalpreservation/ScienceStories/YalePhDs',
#  'User:YULdigitalpreservation/ScienceStories/employedYale',
#  'User:YULdigitalpreservation/Reports',
#  'User:YULdigitalpreservation/lovedata2018',
#  'User:YULdigitalpreservation/ScienceStories/MaxineSinger',
#  'User:Ash_Crow/Brittany',
#  'User:YULdigitalpreservation/ScienceStories/Horstmann',
#  'User:YULdigitalpreservation/Connecticut',
#  'User:YULdigitalpreservation/ScienceStories/NAS',
#  'User:YULdigitalpreservation/ScienceStories/Awards',
#  'User:YULdigitalpreservation/ScienceStories/KJB',
#  'User:YULdigitalpreservation/ScienceStories/Coeducation',
#  'User:Daniel_Mietchen/FSCI_2018',
#  'User:Battleofalma/Queries_I_use',
#  'User:Soh.Miero/sandbox',
#  'User:YULdigitalpreservation/SoftwareCitation',
#  'User:Piecesofuk/Wikidata_Queries',
#  'User:YULdigitalpreservation/equivalentProps',
#  'User:YULdigitalpreservation/ScienceStories/researchFellowYale',
#  'User:YULdigitalpreservation/ScienceStories/MDYale',
#  'User:YULdigitalpreservation/SPARQLsoftware',
#  'User:YULdigitalpreservation/ScienceStories/DataReports',
#  'User:Masssly/Ghana',
#  'User:YULdigitalpreservation/SPARQL2meta',
#  'User:Wassan.anmol',
#  'User:Duesentrieb/WDQL',
#  'User:YULdigitalpreservation/WikiDP',
#  'User:Ijon/Queries',
#  'User:Looniverse/Landtagswahl',
#  'User:Ranjithsiji/Queries',
#  'User:Trade/sandbox',
#  'User:Taravyvan_Adijene/SPARQL',
#  'User:Geertivp/training/WDFIST',
#  'User:Ambrosia10/Query',
#  'User:Flixtey/Queries',
#  'User:Geertivp/training/Wikidata_Query/Family_tree',
#  'User:Realworldobject/sandbox',
#  'User:Digipres',
#  'User:YULdigitalpreservation/SPARQL2019',
#  'User:Jsamwrites/Project_LGBTIQA',
#  'User:YULdigitalpreservation/ValueSetLists',
#  'User:Realworldobject/QueryExamples',
#  'User:YULdigitalpreservation/SoftwareKO',
#  'User:Geertivp/training/Wikidata_Query/Wikimedia/Languages',
#  'User:MKar/MLA',
#  'User:HereinTheHague',
#  'User:Richard_Nevell_(WMUK)',
#  'User:MartinPoulter/queries/calendars',
#  'User:Realworldobject/GraphDBExamples',
#  'User:Looniverse/Europawahl',
#  'User:Sinkra/wikidata',
#  'User:Jaimemf/MonumentosZaragoza',
#  'User:Acagastya/Query',
#  'User:YULdigitalpreservation/moreSPARQL',
#  'User:Jaimemf/DiocesisEspa%C3%B1a',
#  'User:Jaimemf/Santoral',
#  'User:Jaimemf/ObisposConsagrados',
#  'User:Geertivp/training/Wikidata_Query/Missing_Corporate_ID',
#  'User:PierreSelim/State_of_the_Beers',
#  'User:Ash_Crow/xkcd',
#  'User:Culex/SPARQL',
#  'User:YULdigitalpreservation/Whales',
#  'User:Fuzheado/queries',
#  'User:YULdigitalpreservation/nutritionInfo',
#  'User:Indrajitdas/Queries',
#  'User:YULdigitalpreservation/tangle',
#  'User:Gittenburg',
#  'User:Realworldobject/Journals',
#  'User:Geertivp/training/Wikidata_Query/List_of_archives',
#  'User:YULdigitalpreservation/SPARQL2020',
#  'User:Daniel_Mietchen/Sandbox4URLshortening',
#  'User:YULdigitalpreservation/CASE',
#  'User:Daniel_Mietchen/TAU_people/Query',
#  'User:Anthere/Divers',
#  'User:YULdigitalpreservation/shex2020',
#  'User:Alexander_Leisser/Showcase',
#  'User:Geertivp/training/Wikidata_Query/Died_before_Belgium',
#  'User:Geertivp/training/Wikidata_Query/Seismografen_van_Nederland',
#  'User:Geertivp/training/Wikidata_Query/Object_in_non-existing_town',
#  'User:Geertivp/training/Wikidata_Query/Nearby_objects',
#  'User:Juliebirkholz',
#  'User:Gnoeee/Query',
#  'User:Rama/Imaginary_museum',
#  'User:Battleofalma/Building_queries_BL',
#  'User:Geertivp/training/Wikidata_Query/Remove_higher_admin_hierarchy',
#  'User:PAC2/SPARQL_queries',
#  'User:Battleofalma/Arts_queries_showcase',
#  'User:Hofoen/QA',
#  'User:Abdeaitali/sandbox',
#  'User:Netha_Hussain_(WikiCred)/Query_list',
#  'User:Realworldobject/GeographicLevels',
#  'User:AllyD/GalleryArtworks',
#  'User:MKar/TimeQuery',
#  'User:AllyD/ArtistsActivities',
#  'User:Martin_schilliger/Hospitals_and_Institutions_for_use_in_paramedic_services',
#  'User:MKar/Citizen',
#  'User:Dagbani_Wikimedians/SPARQL_queries',
#  'User:Piecesofuk/Wikidata_Queries/HSV',
#  'User:Quinn.hart',
#  'User:MartinPoulter/queries/khalili',
#  'User:Jneubert/SWIB_queries',
#  'User:LiaFla/draft',
#  'User:Tanay_barisha/Queries',
#  'User:Dipsode87/ARK',
#  'User:Geertivp/training/Wikidata/Wiki_projects',
#  'User:Trade/podcasts/query',
#  'User:Realworldobject/LRMExamples',
#  'User:YULdigitalpreservation/trid',
#  'User:M%C3%A1t%C3%A9/%C3%A1t%C3%ADr%C3%A1s',
#  'User:Realworldobject/LexemeExamples',
#  'User:Realworldobject/SHACLExperiments',
#  'User:Realworldobject/AIethics_futures',
#  'User:PAC2/Tour_de_France',
#  'User:Realworldobject/WEMI_correspondence',
#  'User:Envlh/Lexemes_Party',
#  'User:PAC2/D%C3%A9partements',
#  'User:AnnikaHendriksen/De_Boodt_P180',
#  'User:PAC2/Actrices_chanteuses_et_chanteurs_acteurs',
#  'User:Rdrg109/1/1',
#  'User:YULdigitalpreservation/ieee',
#  'User:PAC2/Elections',
#  'User:AHendriksen-collecties/vrouwelijke_Nederlandse_biologen',
#  'User:Susannaanas/Kuka_kuvasi',
#  'User:SCIdude/Rotavirus',
#  'User:YULdigitalpreservation/knowledgeGraphs',
#  'User:Rdrg109/1/21',
#  'User:Jean-Fr%C3%A9d%C3%A9ric/Austria_contest_ideas_bis',
#  'User:Jean-Fr%C3%A9d%C3%A9ric/Austria_contest_ideas_ter',
#  'User:Ijon/Lexeme',
#  'User:AHendriksen-collecties/sandbox',
#  'User:SCIdude/Denguevirus',
#  'User:Susannaanas/SPARQL',
#  'User:EmericusPetro/sandbox/List_of_OpenStreetMap_editors',
#  'User:SCIdude/RSV',
#  'User:Daniel_Mietchen/Query_shortcuts',
#  'User:Daniel_Mietchen/365_climate_edits',
#  'User:Will_(Wiki_Ed)/Queries',
#  'User:Silanoc/donjon',
#  'User:Jean-Fr%C3%A9d%C3%A9ric/Worklab_Graz',
#  'User:Danysan1/Polifonia-Wikidata_matching',
#  'User:Rocky_734/Query',
#  'User:Satpal_Dandiwal/Query',
#  'User:Ayokanmi_(WUGN)/Queries',
#  'User:PAC2/Medias_by_country',
#  'User:AravindIM/Query',
#  'User:Kbseah/queries',
#  'User:Silanoc/BD',
#  'User:Silanoc/Sartrouville',
#  'User:Battleofalma/University_of_Essex',
#  'User:Battleofalma/Congruence_Engine/Textile_Machinery',
#  'User:Battleofalma/UCL',
#  'User:WiK14ot0g/sandbox/test',
#  'User:WiK14ot0g/sandbox/objectlists',
#  'User:Pierre_Tribhou/queries',
#  'User:Gerd_Fahrenhorst/KunstNachOrt',
#  'User:Dipsode87/FormatsSoftware',
#  'User_talk:Jarekt',
#  'User_talk:Ivan_A._Krestinin/Archive',
#  'User_talk:Rama',
#  'User_talk:Datumizer',
#  'User_talk:ArthurPSmith/Archive/4',
#  'User_talk:Jura1/C/30/C/1aruJ:klat_resU',
#  'User_talk:JAn',
#  'Wikidata:Properties/Statistics',
#  'Wikidata:WikiProject_International_relations',
#  'Wikidata:WikiProject_Music',
#  'Wikidata:WikiProject_Ecology',
#  'Wikidata:SPARQL_query_service/queries',
#  'Wikidata:WikiProject_Names/reports',
#  'Wikidata:WikiProject_Sled_dog_racing/Queries',
#  'Wikidata:WikiProject_Cycling/SPARQL',
#  'Wikidata:WikiProject_Music/en',
#  'Wikidata:WikiProject_Music/fr',
#  'Wikidata:WikiProject_Music/uk',
#  'Wikidata:WikiProject_Cultural_heritage/Reports/Ingesting_Swiss_heritage_institutions',
#  'Wikidata:SPARQL_query_service/queries/examples',
#  'Wikidata:Project_chat/Archive/2016/08',
#  'Wikidata:Request_a_query/Archive/2016/08',
#  'Wikidata:WikiProject_Czech_Republic/Showcase_Queries',
#  'Wikidata:Request_a_query/Archive/2016/09',
#  'Wikidata:Bot_requests/Archive/2016/09',
#  'Wikidata:WikiProject_Music/ru',
#  'Wikidata:WikiProject_Theatre/Queries',
#  'Wikidata:WikiProject_Virtual_Twins',
#  'Wikidata:WikiProject_Music/de',
#  'Wikidata:Project_chat/Archive/2016/11',
#  'Wikidata:WikiProject_Heritage_institutions/Tools_%26_tasks',
#  'Wikidata:Bistro/Archive/2016/12',
#  'Wikidata:WikiProject_Aviation/Lists',
#  'Wikidata:WikiProject_Northern_Cemetery_Stockholm_Q252312',
#  'Wikidata:WikiProject_Informatics/Protocols',
#  'Wikidata:Request_a_query/Archive/2017/01',
#  'Wikidata:WikiProject_Figure_skating/Queries',
#  'Wikidata:WDQS_and_Mediawiki_API',
#  'Wikidata:Project_chat/Archive/2017/05',
#  'Wikidata:Requests_for_permissions/Bot/WikiProjectFranceBot',
#  'Wikidata:WikiProject_Zika_Corpus/Queries',
#  'Wikidata:Project_chat/Archive/2017/06',
#  'Wikidata:WikiProject_Informatics/Software/Queries',
#  'Wikidata:Request_a_query/Archive/2017/06',
#  'Wikidata:SBL',
#  'Wikidata:Request_a_query/Archive/2017/07',
#  'Wikidata:Project_chat/Archive/2017/07',
#  'Wikidata:WikiProject_Music/ar',
#  'Wikidata:SPARQL_query_service/queries/examples/en',
#  'Wikidata:SPARQL_query_service/queries/examples/fr',
#  'Wikidata:SPARQL_query_service/queries/examples/de',
#  'Wikidata:SPARQL_query_service/queries/examples/ru',
#  'Wikidata:SPARQL_query_service/queries/examples/cs',
#  'Wikidata:Project_chat/Archive/2017/08',
#  'Wikidata:WikiProject_Goats/Queries',
#  'Wikidata:WikiProject_Music/cs',
#  'Wikidata:Request_a_query/Archive/2017/08',
#  'Wikidata:SPARQL_query_service/queries/examples/es',
#  'Wikidata:SBL/Yrken',
#  'Wikidata:WikidataCon_2017/Program/Visits',
#  'Wikidata:WikiProject_India/Queries',
#  'Wikidata:Request_a_query/Archive/2017/09',
#  'Wikidata:WikiProject_India/Queries/MKar',
#  'Wikidata:SPARQL_query_service/queries/examples/ja',
#  'Wikidata:WikiProject_Las_Imprescindibles/Queries',
#  'Wikidata:SPARQL_query_service/queries/examples/it',
#  'Wikidata:Request_a_query/Archive/2017/11',
#  'Wikidata:Project_chat/Archive/2017/12',
#  'Wikidata:WikiProject_Philosophy',
#  'Wikidata:Request_a_query/Archive/2017/12',
#  'Wikidata:SPARQL_query_service/queries/examples/uk',
#  'Wikidata:SPARQL_query_service/queries/examples/sandbox',
#  'Wikidata:SPARQL_query_service/queries/examples/ca',
#  'Wikidata:Request_a_query/Archive/2018/02',
#  'Wikidata:Request_a_query/Archive/2018/03',
#  'Wikidata:SPARQL_query_service/queries/examples/nl',
#  'Wikidata:SPARQL_query_service/queries/examples/lt',
#  'Wikidata:WikiProject_Music/pl',
#  'Wikidata:SPARQL_query_service/queries/examples/sv',
#  'Wikidata:WikiProject_Music/sv',
#  'Wikidata:SPARQL_query_service/queries/examples/ms',
#  'Wikidata:Request_a_query/Archive/2018/05',
#  'Wikidata:WikiProject_Sustainable_Development',
#  'Wikidata:WikiProject_Eurovision',
#  'Wikidata:SPARQL_query_service/queries/examples/pl',
#  'Wikidata:Request_a_query/Archive/2018/06',
#  'Wikidata:WikiProject_University_degrees/Properties',
#  'Wikidata:WikiProject_University_degrees/Queries',
#  'Wikidata:WikiProject_Music/it',
#  'Wikidata:WikiProject_Biodiversity',
#  'Wikidata:Wikidata_curricula/Activities/Explore_some_SPARQL_queries_to_check_data_quality',
#  'Wikidata:WikiProject_Humanitarian_Wikidata',
#  'Wikidata:WikiProject_Video_games/Queries',
#  'Wikidata:Request_a_query/Archive/2018/08',
#  'Wikidata:WikiProject_Humanitarian_Wikidata/Recent_disasters',
#  'Wikidata:WikiProject_Invasion_biology',
#  'Wikidata:SPARQL_query_service/queries/examples/ko',
#  'Wikidata:SPARQL_query_service/queries/examples/ar',
#  'Wikidata:WikiProject_Music/da',
#  'Wikidata:ContentMine/Cambridge_Wikidata_Workshop/Image_Workshop',
#  'Wikidata:SPARQL_query_service/queries/examples/da',
#  'Wikidata:SPARQL_query_service/queries/examples/eo',
#  'Wikidata:Request_a_query/Archive/2019/01',
#  'Wikidata:WikiProject_Data_Quality',
#  'Wikidata:Forum/Archiv/2019/02',
#  'Wikidata:WikiProject_20th_Century_Press_Archives/Use_cases',
#  'Wikidata:WikiProject_France/Queries/Communes',
#  'Wikidata:WikiProject_France/Queries/Langues',
#  'Wikidata:WikiProject_France/Administrations',
#  'Wikidata:Widawiwo/List_of_Dutch_lexemes',
#  'Wikidata:Widawiwo/List_of_Dutch_lexemes_by_category',
#  'Wikidata:Widawiwo/List_of_Dutch_nouns',
#  'Wikidata:Widawiwo/List_of_Dutch_verbs',
#  'Wikidata:Widawiwo/Count_of_Dutch_lexemes',
#  'Wikidata:WikiProject_University_degrees/Reports/Bulgaria',
#  'Wikidata:WikiProject_University_degrees/Reports/Costa_Rica',
#  'Wikidata:WikiProject_University_degrees/Reports/Iceland',
#  'Wikidata:WikiProject_University_degrees/Reports/Malta',
#  'Wikidata:WikiProject_University_degrees/Reports/Portugal',
#  'Wikidata:WikiProject_University_degrees/Reports/Fiji',
#  'Wikidata:WikiProject_University_degrees/Reports/Ireland',
#  'Wikidata:WikiProject_Women/Wiki_monitor/Statistics',
#  'Wikidata:WikiProject_University_degrees/Reports/New_Zealand',
#  'Wikidata:SPARQL_query_service/queries/examples/si',
#  'Wikidata:Request_a_query/Archive/2019/08',
#  'Wikidata:WikiProject_LGBT/Queries',
#  'Wikidata:SPARQL_query_service/queries/examples/pt-br',
#  'Wikidata:WikiProject_Music/gu',
#  'Wikidata:Request_a_query/Archive/2019/09',
#  'Wikidata:Request_a_query/Archive/2019/10',
#  'Wikidata:WikiProject_African_Diaspora',
#  'Wikidata:WikiProject_Scholia/Robustifying/Testing',
#  'Wikidata:SPARQL_query_service/queries/examples/zh',
#  'Wikidata:SPARQL_query_service/queries/examples/advanced',
#  'Wikidata:WikiProject_Music/nl',
#  'Wikidata:WikiCite/Wikidata_lists/Usage_of_Template_Scholia/Cross-wiki/Query',
#  'Wikidata:WikiCite/Wikidata_lists/Usage_of_Template_Scholia/English_Wikipedia/Query',
#  'Wikidata:WikiProject_Medicine/Talks/Wikimedia_for_Medicine_course_at_Tel_Aviv_University_2020',
#  'Wikidata:WikiProject_Clinical_Trials/Query',
#  'Wikidata:SPARQL_query_service/queries/examples/he',
#  'Wikidata:Events/Belgium/Open_Knowledge_Belgium/Towards_Equal_Street_Names_with_Open_Data',
#  'Wikidata:Events/Belgium/Open_Knowledge_Belgium/RTBF_Wikipedia_Marathon',
#  'Wikidata:Request_a_query/Archive/2020/02',
#  'Wikidata:WikiProject_COVID-19/Queries',
#  'Wikidata:Request_a_query/Archive/2020/03',
#  'Wikidata:WikiProject_Linked_Data_for_Production/2020-03-20_Wikidata_Working_Hour',
#  'Wikidata:WikiProject_Linked_Data_for_Production/2020-03-30',
#  'Wikidata:Events/Belgium/Wikimedia_Belgium/Erfgoed/Pajottenland-Zennevallei',
#  'Wikidata:WikiProject_Linked_Data_for_Production/2020-04-17_Wikidata_Working_Hour',
#  'Wikidata:WikiProject_COVID-19/Focus_list',
#  'Wikidata:Events/Belgium/CEMPER/Person_without_Wikipedia_page',
#  'Wikidata:Request_a_query/Archive/2020/04',
#  'Wikidata:Wikidata_curricula/Activities/Find_Commons_Creator_page_without_Commons_category',
#  'Wikidata:WikiProject_Linked_Data_for_Production/2020-04-27_Wikidata_Working_Hour',
#  'Wikidata:WikiProject_Linked_Data_for_Production/2020-05-15_Wikidata_Working_Hour',
#  'Wikidata:Project_chat/Archive/2020/05',
#  'Wikidata:Request_a_query/Archive/2020/05',
#  'Wikidata:SPARQL_query_service/queries/examples/ro',
#  'Wikidata:Science_Museum',
#  'Wikidata:WikiProject_Protected_areas/Queries',
#  'Wikidata:WikiProject_Linked_Data_for_Production/2020-05-29_Wikidata_Working_Hour',
#  'Wikidata:WikiProject_Hospitals/Queries',
#  'Wikidata:Events/Belgium/Wikimedia_Belgium/Erfgoed/Randfenomenen_locaties',
#  'Wikidata:Request_a_query/Archive/2020/06',
#  'Wikidata:WikiProject_Hospitals/Report/Regensburg',
#  'Wikidata:WikiProject_Hospitals/Report/Nuremberg',
#  'Wikidata:SPARQL_query_service/queries/examples/advanced/en',
#  'Wikidata:WikiProject_Chemistry_Natural_products',
#  'Wikidata:WikiProject_Hospitals/Report/Potsdam',
#  'Wikidata:WikiProject_Informatics/Hardware/Tablet_computers',
#  'Wikidata:WikiProject_Informatics/Hardware/Mobile_phones',
#  'Wikidata:WikiProject_Informatics/Protocols/IP',
#  'Wikidata:WikiProject_Informatics/Protocols/TCP',
#  'Wikidata:WikiProject_Informatics/Protocols/UDP',
#  'Wikidata:WikiProject_Informatics/Protocols/SCTP',
#  'Wikidata:WikiProject_Linked_Data_for_Production/LD4_2020_Conference-LD4_Wikidata_Affinity_Group_Wikidata_Working_Hour:_Adding_References_to_Wikidata',
#  'Wikidata:WikiProject_Kerala/Queries',
#  'Wikidata:WikiProject_COVID-19/Queries/SPARQL_Study',
#  'Wikidata:SPARQL_query_service/queries/examples/tr',
#  'Wikidata:WikiProject_Linked_Data_for_Production/2020-09-14_Wikidata_Working_Hour',
#  'Wikidata:WikiProject_Linked_Data_for_Production/2020-October-02_Wikidata_Working_Hour',
#  'Wikidata:WikiProject_PCC_Wikidata_Pilot/UC_Davis/Example_Queries',
#  'Wikidata:WikiProject_Music/hy',
#  'Wikidata:WikiProject_Linked_Data_for_Production/2020-October-12_Wikidata_Working_Hour',
#  'Wikidata:Project_chat/Archive/2020/10',
#  'Wikidata:WikiProject_Linked_Data_for_Production/2020-10-20_Wikidata_Working_Hour',
#  'Wikidata:WikiProject_Indonesia/Kueri',
#  'Wikidata:WikiProject_PCC_Wikidata_Pilot/UC_Davis/Organizations',
#  'Wikidata:WikiProject_Linked_Data_for_Production/2020-November-9_Wikidata_Working_Hour',
#  'Wikidata:Request_a_query/Archive/2020/11',
#  'Wikidata:SPARQL_query_service/queries/examples/advanced/sv',
#  'Wikidata:SPARQL_query_service/queries/examples/be-tarask',
#  'Wikidata:WikiProject_IFRC/Queries',
#  'Wikidata:SPARQL_query_service/queries/examples/advanced/uk',
#  'Wikidata:SPARQL_query_service/queries/examples/advanced/es',
#  'Wikidata:WikiProject_Medicine/Talks/Wikimedia_for_Medicine_course_at_Tel_Aviv_University_2021',
#  'Wikidata:SPARQL_query_service/queries/examples/id',
#  'Wikidata:Art%2BFeminism_User_Group/Query_examples',
#  'Wikidata:Request_a_query/Archive/2021/02',
#  'Wikidata:WikiProject_PCC_Wikidata_Pilot/UC_Davis/Faculty',
#  'Wikidata:WikiProject_Templates/SPARQL_templates',
#  'Wikidata:WikiProject_Local_Community',
#  'Wikidata:WikiProject_LD4_Wikidata_Affinity_Group/Wikidata_Working_Hours/2021-March-29_Wikidata_Working_Hour_in_Wikidata',
#  'Wikidata:Making_sense',
#  'Wikidata:SPARQL_query_service/queries/examples/advanced/tr',
#  'Wikidata:WikiProject_LD4_Wikidata_Affinity_Group/Wikidata_Working_Hours/2021-April-26_Wikidata_Working_Hour',
#  'Wikidata:WikiProject_Podcasts/Queries',
#  'Wikidata:WikiProject_India_Office_Records',
#  'Wikidata:Lexicographical_data/Documentation/Languages/id',
#  'Wikidata:WikiProject_Ethics',
#  'Wikidata:Lexicographical_data/Documentation/Languages/hi',
#  'Wikidata:Lexicographical_data/Documentation/Languages/ta',
#  'Wikidata:Lexicographical_data/Documentation/Languages/te',
#  'Wikidata:Lexicographical_data/Documentation/Languages/or',
#  'Wikidata:SPARQL_query_service/queries/examples/advanced/fr',
#  'Wikidata:WikiProject_Music/tr',
#  'Wikidata:WikiProject_Informatics/Hardware/Supercomputers',
#  'Wikidata:WikiProject_Invasion_biology/Task_Force_Hi_Knowledge',
#  'Wikidata:Requests_for_comment/How_to_avoid_to_use_male_form_as_a_generic_form_in_property_labels_in_French%3F',
#  'Wikidata:WikiProject_Country_subdivision/Ghana',
#  'Wikidata:WikiProject_Ecology/Task_Force_Urban_Ecology',
#  'Wikidata:WikiCite/Dagbani',
#  'Wikidata:SPARQL_query_service/queries/examples/hy',
#  'Wikidata:SPARQL_query_service/queries/examples/advanced/hy',
#  'Wikidata:WikiProject_Music/ja',
#  'Wikidata:SPARQL_query_service/queries/examples/vec',
#  'Wikidata:SPARQL_query_service/queries/examples/en-gb',
#  'Wikidata:CopyClear/Lakenhal/export',
#  'Wikidata:SPARQL_query_service/queries/examples/eu',
#  'Wikidata:WikiProject_Slovakia/Properties',
#  'Wikidata:WikiProject_Slovakia/Showcase_Queries',
#  'Wikidata:WikiProject_Slovakia/Properties/en',
#  'Wikidata:WikiProject_Slovakia/Showcase_Queries/en',
#  'Wikidata:WikiProject_Slovakia/Properties/cs',
#  'Wikidata:WikiProject_Slovakia/Showcase_Queries/cs',
#  'Wikidata:SPARQL_query_service/queries/examples/advanced/zh',
#  'Wikidata:Request_a_query/Archive/2022/05',
#  'Wikidata:WikiProject_Biography/Query',
#  'Wikidata:Michael_Marks_Awards_for_Poetry_Pamphlets',
#  'Wikidata:Request_a_query/Archive/2022/06',
#  'Wikidata:WikiProject_Government/Queries',
#  'Wikidata:WikiProject_UAE/Queries',
#  'Wikidata:Naturalis',
#  'Wikidata:Request_a_query/Archive/2022/08',
#  'Wikidata:WikiProject_Climate_Change/IPCC_reports',
#  'Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries',
#  'Wikidata:WikiProject_OBO',
#  'Wikidata:WikiProject_OBO/Disease_Ontology',
#  'Wikidata:WikiProject_Slovakia/Properties/da',
#  'Wikidata:WikiProject_Civil_Defense/List_of_emergency_management_governmental_agencies',
#  '']

# %%
import re
import os
import requests

template_prefix = """@prefix ex: <https://sparql.uniprot.org/.well-known/sparql-examples/> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix schema: <https://schema.org/> .
@prefix sh: <http://www.w3.org/ns/shacl#> .
@prefix wiki: <https://www.wikidata.org/wiki/> .

"""

template_body = """ex:{title} a sh:SPARQLExecutable,
        sh:SPARQLSelectExecutable ;
    rdfs:comment "{comment}"^^rdf:HTML ;
    dcterms:license <https://creativecommons.org/licenses/by-sa/4.0/> ;
    dcterms:isVersionOf {wikiurl} ;
    sh:select """ + '"""' + """
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wds: <http://www.wikidata.org/entity/statement/>
PREFIX wdv: <http://www.wikidata.org/value/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX p: <http://www.wikidata.org/prop/>
PREFIX ps: <http://www.wikidata.org/prop/statement/>
PREFIX pq: <http://www.wikidata.org/prop/qualifier/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX bd: <http://www.bigdata.com/rdf#>

PREFIX wdref: <http://www.wikidata.org/reference/>
PREFIX psv: <http://www.wikidata.org/prop/statement/value/>
PREFIX psn: <http://www.wikidata.org/prop/statement/value-normalized/>
PREFIX pqv: <http://www.wikidata.org/prop/qualifier/value/>
PREFIX pqn: <http://www.wikidata.org/prop/qualifier/value-normalized/>
PREFIX pr: <http://www.wikidata.org/prop/reference/>
PREFIX prv: <http://www.wikidata.org/prop/reference/value/>
PREFIX prn: <http://www.wikidata.org/prop/reference/value-normalized/>
PREFIX wdno: <http://www.wikidata.org/prop/novalue/>
PREFIX wdata: <http://www.wikidata.org/wiki/Special:EntityData/>

PREFIX schema: <http://schema.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX bds: <http://www.bigdata.com/rdf/search#>
PREFIX gas: <http://www.bigdata.com/rdf/gas#>
PREFIX hint: <http://www.bigdata.com/queryHints#>

{query}
""" + '"""' + """ ;
    schema:target <https://query.wikidata.org/sparql/> .
"""

# Function to generate SPARQL template
def generate_sparql_template(file_name, sparql_query, wikiurl):
    title = file_name.replace('.rq', '')
    comment = f"Sparql query from file {file_name}"
    return template_prefix + template_body.format(title=title, comment=comment, query=sparql_query, wikiurl=wikiurl)


for line in lines:
    # Create a directory named after the line
    wikiURL = f"<https://www.wikidata.org/wiki/{line}>"
    directory_name = "sparqlrdf/" + line.replace(" ", "_")  # Replace spaces with underscores for the directory name
    os.makedirs(directory_name, exist_ok=True)
    
    # Fetch the content of the page
    uri = f"https://www.wikidata.org/w/api.php?action=query&prop=revisions&rvprop=content&format=json&formatversion=2&titles={line}"
    response = requests.get(uri)
    data = response.json()
    
    # Extract the wikitext content
    try:
        wikitext = data["query"]["pages"][0]["revisions"][0]["content"]
    except (IndexError, KeyError):
        print(f"Error fetching content for {line}")
        continue

    # Regular expression pattern to match {{sparql ...}} and {{sparql2 ...}}, case insensitive
    pattern = r'{{sparql2?.*?}}'
    snippets = re.findall(pattern, wikitext, re.DOTALL | re.IGNORECASE)
    
    # Write each snippet to a separate .ttl file
    for i, snippet in enumerate(snippets):
        # Clean up snippet by removing the template markup
        clean_snippet = re.sub(r"^\{\{sparql2?\|query=", "", snippet, flags=re.IGNORECASE)
        clean_snippet = re.sub(r"\}\}$", "", clean_snippet)
        
        # Generate the SPARQL template
        file_name = f"snippet_{i + 1}.ttl"
        full_file_path = os.path.join(directory_name, file_name)
        sparql_template = generate_sparql_template(full_file_path, clean_snippet, wikiURL)
        
        # Save the SPARQL template to a file
        
        with open(full_file_path, "w", encoding="utf-8") as file:
            file.write(sparql_template)
            
        print(f"Snippet saved to {full_file_path}")
# Out:
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_emergency_medical_services_organizations/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_rescue_organizations/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_law_enforcement_agencies/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_law_enforcement_agencies/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_law_enforcement_agencies/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_law_enforcement_agencies/Brazil/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_nuclear_power_plants/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_dykes/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_dams/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_dams/Brazil/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_shelters/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_firefighting_organizations/Brazil/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_aerodromes/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_aerodromes/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_aerodromes/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_IFRC/List/Tree/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_IFRC/List/Tree/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_20th_Century_Press_Archives/Tools_%26_Tasks/Subject_Category_checks/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_20th_Century_Press_Archives/Tools_%26_Tasks/Subject_Category_checks/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_20th_Century_Press_Archives/Tools_%26_Tasks/Subject_Category_checks/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_20th_Century_Press_Archives/Tools_%26_Tasks/Subject_Category_checks/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_20th_Century_Press_Archives/Tools_%26_Tasks/Subject_Category_checks/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_20th_Century_Press_Archives/Tools_%26_Tasks/Subject_Category_checks/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_20th_Century_Press_Archives/Tools_%26_Tasks/Subject_Category_checks/snippet_7.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Climate_Change/Queries/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Climate_Change/Queries/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Climate_Change/Queries/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Climate_Change/Queries/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Climate_Change/Queries/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Climate_Change/Queries/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Climate_Change/Models/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_emergency_management_governmental_agencies/419/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_crematories/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_crematories/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Slovakia/Properties/szl/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_7.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_8.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_9.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_10.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_11.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_12.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_13.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_14.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_15.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_16.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_17.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_18.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_19.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_20.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_21.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_22.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_23.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_24.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_25.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_26.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_27.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_28.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_29.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_30.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_31.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_32.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_33.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_34.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_35.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_36.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_37.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_38.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_39.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_40.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_41.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_42.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_43.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_44.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_45.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_46.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_47.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_48.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_49.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_50.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_51.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_52.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_53.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_54.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_55.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_56.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_57.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_58.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_59.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_60.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_61.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_62.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_63.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_64.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_65.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_66.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_67.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_68.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_69.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_70.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_71.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_72.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_73.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_74.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_75.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_76.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_77.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_78.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_79.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_80.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_81.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_82.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_83.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_84.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_85.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_86.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_87.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_88.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_89.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_90.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_91.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_92.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_93.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_94.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_95.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_96.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_97.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_98.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_99.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_100.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_101.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_102.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_103.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_104.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_105.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_106.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_107.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_108.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_109.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_110.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_111.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_112.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_113.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_114.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_115.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_116.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_117.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_118.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_119.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_120.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_121.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_122.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_123.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_124.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_125.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_126.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_127.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_128.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_129.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_130.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_131.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_132.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_133.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_134.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_135.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_136.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_137.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_138.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_139.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_140.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_141.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_142.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_143.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_144.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_145.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_146.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_147.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_148.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_149.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_150.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_151.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_152.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_153.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_154.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_155.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_156.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_157.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_158.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_159.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_160.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_161.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_162.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_163.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_164.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_165.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_166.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_167.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_168.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_169.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_170.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_171.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_172.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_173.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_174.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_175.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_176.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_177.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_178.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_179.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_180.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_181.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_182.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_183.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_184.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_185.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_186.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_187.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_188.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_189.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_190.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_191.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_192.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_193.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_194.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_195.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_196.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_197.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_198.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_199.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_200.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_201.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_202.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_203.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_204.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_205.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_206.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_207.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_208.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_209.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_210.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_211.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_212.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_213.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_214.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_215.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_216.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_217.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_218.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_219.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_220.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_221.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_222.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_223.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_224.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_225.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_226.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_227.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_228.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_229.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_230.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_231.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_232.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_233.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_234.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_235.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_236.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_237.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_238.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_239.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_240.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_241.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_242.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_243.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_244.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_245.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_246.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_247.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_248.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_249.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_250.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_251.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_252.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_253.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_254.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_255.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_256.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_257.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_258.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_259.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_260.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_261.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_262.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_263.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_264.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_265.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_266.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_267.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_268.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_269.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_270.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_271.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_272.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_273.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_274.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_275.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_276.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_277.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_278.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_279.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_280.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_281.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_282.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_283.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_284.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_285.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_286.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_287.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_288.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_289.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_290.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_291.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_292.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_293.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_294.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_295.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_296.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_297.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_298.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_299.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_300.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_301.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_302.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_303.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_304.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_305.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_306.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_307.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_308.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_309.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_310.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_311.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_312.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_313.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_314.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_315.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_316.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_317.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_318.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_319.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_320.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_321.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_322.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_323.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_324.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_325.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_326.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_327.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_328.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_329.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_330.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_331.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_332.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_333.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_334.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_335.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_336.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_337.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_338.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_339.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_340.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_341.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_342.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_343.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_344.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_345.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_346.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_347.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_348.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_349.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_350.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_351.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_352.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_353.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_354.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_355.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_356.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_357.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_358.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_359.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_360.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_361.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_362.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_363.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_364.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_365.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_366.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_367.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_368.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_369.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_370.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_371.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_372.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_373.ttl
# Snippet saved to sparqlrdf/Wikidata:SPARQL_query_service/queries/examples/th/snippet_374.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/es/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/es/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/es/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/es/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:Open-source_hardware/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/ms-arab/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/ms-arab/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/ms-arab/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/ms-arab/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/ms/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/ms/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/ms/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/ms/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_7.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_8.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_9.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_10.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_11.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_12.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_13.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_14.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_15.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_16.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_17.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_18.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_19.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_20.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/en/snippet_21.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_7.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_8.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_9.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_10.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_11.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_12.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_13.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_14.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_15.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_16.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_17.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_18.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_19.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_20.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/fr/snippet_21.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/bn/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/bn/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/bn/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/bn/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/syl/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/syl/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/syl/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Music/syl/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_7.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_8.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_9.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_10.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_11.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_12.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_13.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_14.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_15.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_16.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_17.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_18.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_19.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_20.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/ru/snippet_21.ttl
# Snippet saved to sparqlrdf/Wikidata:Lexicographical_data/Malayalam/Queries/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:Lexicographical_data/Malayalam/Queries/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_7.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_8.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_9.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_10.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_11.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_12.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_13.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_14.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_15.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_16.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_17.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_18.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_19.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_20.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/it/snippet_21.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Report/Greenland/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Chemistry_Natural_products/de/snippet_1.ttl
# ...
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/05/snippet_30.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/05/snippet_31.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/05/snippet_32.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/05/snippet_33.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Biography/Query/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Biography/Query/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Biography/Query/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Biography/Query/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Biography/Query/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Biography/Query/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Biography/Query/snippet_7.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Biography/Query/snippet_8.ttl
# Snippet saved to sparqlrdf/Wikidata:Michael_Marks_Awards_for_Poetry_Pamphlets/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:Michael_Marks_Awards_for_Poetry_Pamphlets/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:Michael_Marks_Awards_for_Poetry_Pamphlets/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:Michael_Marks_Awards_for_Poetry_Pamphlets/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_7.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_8.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_9.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_10.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_11.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_12.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_13.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_14.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_15.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_16.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_17.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_18.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_19.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_20.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_21.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_22.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_23.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_24.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_25.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_26.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_27.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_28.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_29.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_30.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_31.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_32.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_33.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_34.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_35.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_36.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_37.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_38.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_39.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_40.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_41.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_42.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_43.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_44.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_45.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_46.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/06/snippet_47.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_7.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_8.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_9.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_10.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_11.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Government/Queries/snippet_12.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_UAE/Queries/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_UAE/Queries/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:Naturalis/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_7.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_8.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_9.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_10.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_11.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_12.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_13.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_14.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_15.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_16.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_17.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_18.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_19.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_20.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_21.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_22.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_23.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_24.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_25.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_26.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_27.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_28.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_29.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_30.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_31.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_32.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_33.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_34.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_35.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_36.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_37.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_38.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_39.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_40.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_41.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_42.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_43.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_44.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_45.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_46.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_47.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_48.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_49.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_50.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_51.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_52.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_53.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_54.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_55.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_56.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_57.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_58.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_59.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_60.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_61.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_62.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_63.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_64.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_65.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_66.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_67.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_68.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_69.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_70.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_71.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_72.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_73.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_74.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_75.ttl
# Snippet saved to sparqlrdf/Wikidata:Request_a_query/Archive/2022/08/snippet_76.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Climate_Change/IPCC_reports/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_5.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_6.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_7.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_8.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_9.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_10.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_11.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_12.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_13.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_14.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_15.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_16.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_17.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_18.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_19.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_20.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_21.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_22.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_23.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_24.ttl
# Snippet saved to sparqlrdf/Wikidata:Tenth_Birthday/DACH_Culture_Contest/queries/snippet_25.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_OBO/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_OBO/Disease_Ontology/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_OBO/Disease_Ontology/snippet_2.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_OBO/Disease_Ontology/snippet_3.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_OBO/Disease_Ontology/snippet_4.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Slovakia/Properties/da/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_emergency_management_governmental_agencies/snippet_1.ttl
# Snippet saved to sparqlrdf/Wikidata:WikiProject_Civil_Defense/List_of_emergency_management_governmental_agencies/snippet_2.ttl
# Error fetching content for

# %%
print(len(lines))
# Out:
# 609
